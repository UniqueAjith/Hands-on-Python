# %% [markdown]
# # Pandas part 1

# %%
import pandas as pd
import numpy as np

# %%
#series
lst = [10,20,30]
pd.Series(data=lst)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
lst1=['a','b','c']
pd.Series(data=lst,index=lst1)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
arr=np.array(['aa','bb','cc'])
pd.Series(data=arr)
# Out:
# 0    aa
# 1    bb
# 2    cc
# dtype: object

# %%
pd.Series(data=arr,index=lst1)
# Out:
# a    aa
# b    bb
# c    cc
# dtype: object

# %%
dict ={'a':10,'b':20,'c':30 }
pd.Series(dict)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
sum1 = pd.Series(data=[1,2,3,4],index=['ajith','bhaghat','madhan','siva'])
sum1
# Out:
# ajith      1
# bhaghat    2
# madhan     3
# siva       4
# dtype: int64

# %%
sum2 = pd.Series(data=[1,2,5,4],index=['ajith','bhaghat','vengi','siva'])
sum2
# Out:
# ajith      1
# bhaghat    2
# vengi      5
# siva       4
# dtype: int64

# %%
sum1 + sum2
# Out:
# ajith      2.0
# bhaghat    4.0
# madhan     NaN
# siva       8.0
# vengi      NaN
# dtype: float64

# %%
sum1 = pd.Series(index=[1,2,3,4],data=['ajith','bhaghat','madhan','siva'])
sum1
# Out:
# 1      ajith
# 2    bhaghat
# 3     madhan
# 4       siva
# dtype: object

# %%
sum2 = pd.Series(index=[1,2,5,4],data=['ajith','bhaghat','vengi','siva'])
sum2
# Out:
# 1      ajith
# 2    bhaghat
# 5      vengi
# 4       siva
# dtype: object

# %%
sum1 + sum2
# Out:
# 1        ajithajith
# 2    bhaghatbhaghat
# 3               NaN
# 4          sivasiva
# 5               NaN
# dtype: object

# %%
#dataframe
from numpy.random import randn

# %%
df=pd.DataFrame(data=randn(6,4),index='A B C D E F'.split(),columns='G H I J'.split())

# %%
df
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641
# F -1.482936 -0.382740 -0.261279  0.664433

# %%
df.head()
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641

# %%
#indexing
df['G']
# Out:
# A    0.000731
# B    1.845575
# C    1.074184
# D   -0.334378
# E    0.993675
# F   -1.482936
# Name: G, dtype: float64

# %%
df[['G','J']]
# Out:
#           G         J
# A  0.000731 -0.677487
# B  1.845575 -0.136334
# C  1.074184  0.249743
# D -0.334378 -0.144672
# E  0.993675 -0.299641
# F -1.482936  0.664433

# %%
type(df['I'])
# Out:
# pandas.core.series.Series

# %%
#create a new column
df['K'] = df['G'] + df['J']
df
# Out:
#           G         H         I         J         K
# A  0.000731 -0.336899  1.489525 -0.677487 -0.676756
# B  1.845575 -1.976139  1.000702 -0.136334  1.709240
# C  1.074184 -0.583584  0.635982  0.249743  1.323927
# D -0.334378 -0.643271  0.241012 -0.144672 -0.479050
# E  0.993675  0.092813 -1.737748 -0.299641  0.694035
# F -1.482936 -0.382740 -0.261279  0.664433 -0.818504

# %%
#remove column
df.drop('K',axis=1)
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641
# F -1.482936 -0.382740 -0.261279  0.664433

# %%
df.drop('F')
# Out:
#           G         H         I         J         K
# A  0.000731 -0.336899  1.489525 -0.677487 -0.676756
# B  1.845575 -1.976139  1.000702 -0.136334  1.709240
# C  1.074184 -0.583584  0.635982  0.249743  1.323927
# D -0.334378 -0.643271  0.241012 -0.144672 -0.479050
# E  0.993675  0.092813 -1.737748 -0.299641  0.694035

# %%
df.drop('F',axis=0)
# Out:
#           G         H         I         J         K
# A  0.000731 -0.336899  1.489525 -0.677487 -0.676756
# B  1.845575 -1.976139  1.000702 -0.136334  1.709240
# C  1.074184 -0.583584  0.635982  0.249743  1.323927
# D -0.334378 -0.643271  0.241012 -0.144672 -0.479050
# E  0.993675  0.092813 -1.737748 -0.299641  0.694035

# %%
df.drop('K',axis=1,inplace=True)
df
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641
# F -1.482936 -0.382740 -0.261279  0.664433

# %%
df.loc['A']
# Out:
# G    0.000731
# H   -0.336899
# I    1.489525
# J   -0.677487
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# G    1.074184
# H   -0.583584
# I    0.635982
# J    0.249743
# Name: C, dtype: float64

# %%
#slice
df.loc['A','I']
# Out:
# 1.4895248149057323

# %%
df.loc[['A','C'],['G','I']]
# Out:
#           G         I
# A  0.000731  1.489525
# C  1.074184  0.635982

# %%
#condition
df
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641
# F -1.482936 -0.382740 -0.261279  0.664433

# %%
df>0
# Out:
#        G      H      I      J
# A   True  False   True  False
# B   True  False   True  False
# C   True  False   True   True
# D  False  False   True  False
# E   True   True  False  False
# F  False  False  False   True

# %%
df[df>0]
# Out:
#           G         H         I         J
# A  0.000731       NaN  1.489525       NaN
# B  1.845575       NaN  1.000702       NaN
# C  1.074184       NaN  0.635982  0.249743
# D       NaN       NaN  0.241012       NaN
# E  0.993675  0.092813       NaN       NaN
# F       NaN       NaN       NaN  0.664433

# %%
df[df['G']>0]
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# E  0.993675  0.092813 -1.737748 -0.299641

# %%
df[(df['G']>0) & (df['I']>1)]
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334

# %%
df
# Out:
#           G         H         I         J
# A  0.000731 -0.336899  1.489525 -0.677487
# B  1.845575 -1.976139  1.000702 -0.136334
# C  1.074184 -0.583584  0.635982  0.249743
# D -0.334378 -0.643271  0.241012 -0.144672
# E  0.993675  0.092813 -1.737748 -0.299641
# F -1.482936 -0.382740 -0.261279  0.664433

# %%
df.reset_index()
# Out:
#   index         G         H         I         J
# 0     A  0.000731 -0.336899  1.489525 -0.677487
# 1     B  1.845575 -1.976139  1.000702 -0.136334
# 2     C  1.074184 -0.583584  0.635982  0.249743
# 3     D -0.334378 -0.643271  0.241012 -0.144672
# 4     E  0.993675  0.092813 -1.737748 -0.299641
# 5     F -1.482936 -0.382740 -0.261279  0.664433

# %%
df['index']='AA BB CC DD EE FF'.split()
df
# Out:
#           G         H         I         J index
# A  0.000731 -0.336899  1.489525 -0.677487    AA
# B  1.845575 -1.976139  1.000702 -0.136334    BB
# C  1.074184 -0.583584  0.635982  0.249743    CC
# D -0.334378 -0.643271  0.241012 -0.144672    DD
# E  0.993675  0.092813 -1.737748 -0.299641    EE
# F -1.482936 -0.382740 -0.261279  0.664433    FF

# %%
df.set_index('index')
# Out:
#               G         H         I         J
# index
# AA     0.000731 -0.336899  1.489525 -0.677487
# BB     1.845575 -1.976139  1.000702 -0.136334
# CC     1.074184 -0.583584  0.635982  0.249743
# DD    -0.334378 -0.643271  0.241012 -0.144672
# EE     0.993675  0.092813 -1.737748 -0.299641
# FF    -1.482936 -0.382740 -0.261279  0.664433

# %%
df
# Out:
#           G         H         I         J index
# A  0.000731 -0.336899  1.489525 -0.677487    AA
# B  1.845575 -1.976139  1.000702 -0.136334    BB
# C  1.074184 -0.583584  0.635982  0.249743    CC
# D -0.334378 -0.643271  0.241012 -0.144672    DD
# E  0.993675  0.092813 -1.737748 -0.299641    EE
# F -1.482936 -0.382740 -0.261279  0.664433    FF

# %%
df.set_index('index',inplace=True)

# %%
df
# Out:
#               G         H         I         J
# index
# AA     0.000731 -0.336899  1.489525 -0.677487
# BB     1.845575 -1.976139  1.000702 -0.136334
# CC     1.074184 -0.583584  0.635982  0.249743
# DD    -0.334378 -0.643271  0.241012 -0.144672
# EE     0.993675  0.092813 -1.737748 -0.299641
# FF    -1.482936 -0.382740 -0.261279  0.664433

# %% [markdown]
# # Pandas part 2

# %% [markdown]
# First import the File

# %%
import numpy as np
import pandas as pd

# %%
#multi-index and Hierchy index
outside = ['g1','g1','g1','g2','g2','g2']
inside = [1,2,3,1,2,3]
index = list(zip(outside,inside))
hier_index= pd.MultiIndex.from_tuples(index)
hier_index
# Out:
# MultiIndex([('g1', 1),
#             ('g1', 2),
#             ('g1', 3),
#             ('g2', 1),
#             ('g2', 2),
#             ('g2', 3)],
#            )

# %%
df = pd.DataFrame(data=np.random.randn(6,3),index=hier_index,columns=['A','B','c'])
df
# Out:
#              A         B         c
# g1 1 -0.324428  0.616937 -2.097212
#    2  0.264823 -1.129241 -0.654513
#    3  0.978031  0.872003  0.171276
# g2 1  1.687012  0.472241  0.363513
#    2 -0.606556 -0.017000  0.599550
#    3 -0.328556 -1.742449 -0.249660

# %%
#missing data
df = pd.DataFrame(data={
    'a':[1,2,np.nan],
    'b':[5,np.nan,np.nan],
    'c':[1,2,3]
})
df
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      a    b  c
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    c
# 0  1
# 1  2
# 2  3

# %%
df.fillna(value=5)
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  5.0  5.0  3

# %%
df['b'].fillna(value=df['c'].mean())
# Out:
# 0    5.0
# 1    2.0
# 2    2.0
# Name: b, dtype: float64

# %%
df['c'].mean()
# Out:
# 2.0

# %%
#read csv file

# %%
ls
# Out:
# data.csv  heart.csv  sample_data/

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0   40   M           ATA  ...      0.0        Up             0
# 1   49   F           NAP  ...      1.0      Flat             1
# 2   37   M           ATA  ...      0.0        Up             0
# 3   48   F           ASY  ...      1.5      Flat             1
# 4   54   M           NAP  ...      0.0        Up             0
#
# [5 rows x 12 columns]

# %%
df
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up             0
# 1     49   F           NAP  ...      1.0      Flat             1
# 2     37   M           ATA  ...      0.0        Up             0
# 3     48   F           ASY  ...      1.5      Flat             1
# 4     54   M           NAP  ...      0.0        Up             0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat             1
# 914   68   M           ASY  ...      3.4      Flat             1
# 915   57   M           ASY  ...      1.2      Flat             1
# 916   57   F           ATA  ...      0.0      Flat             1
# 917   38   M           NAP  ...      0.0        Up             0
#
# [918 rows x 12 columns]

# %%
df.to_string()
# Out:
# '     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease\n0     40   M           ATA        140          289          0     Normal    172              N      0.0       Up             0\n1     49   F           NAP        160          180          0     Normal    156              N      1.0     Flat             1\n2     37   M           ATA        130          283          0         ST     98              N      0.0       Up             0\n3     48   F           ASY        138          214          0     Normal    108              Y      1.5     Flat             1\n4     54   M           NAP        150          195          0     Normal    122              N      0.0       Up             0\n5     39   M           NAP        120          339          0     Normal    170              N      0.0       Up             0\n6     45   F           ATA        130          237          0     Normal    170              N      0
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0   40   M           ATA  ...      0.0        Up             0
# 1   49   F           NAP  ...      1.0      Flat             1
# 2   37   M           ATA  ...      0.0        Up             0
# 3   48   F           ASY  ...      1.5      Flat             1
# 4   54   M           NAP  ...      0.0        Up             0
#
# [5 rows x 12 columns]

# %%
df.mean()
# Out:
# Age              53.510893
# RestingBP       132.396514
# Cholesterol     198.799564
# FastingBS         0.233115
# MaxHR           136.809368
# Oldpeak           0.887364
# HeartDisease      0.553377
# dtype: float64

# %%
df.std()
# Out:
# Age               9.432617
# RestingBP        18.514154
# Cholesterol     109.384145
# FastingBS         0.423046
# MaxHR            25.460334
# Oldpeak           1.066570
# HeartDisease      0.497414
# dtype: float64

# %%
df.min()
# Out:
# Age                 28
# Sex                  F
# ChestPainType      ASY
# RestingBP            0
# Cholesterol          0
# FastingBS            0
# RestingECG         LVH
# MaxHR               60
# ExerciseAngina       N
# Oldpeak           -2.6
# ST_Slope          Down
# HeartDisease         0
# dtype: object

# %%
df.max()
# Out:
# Age                77
# Sex                 M
# ChestPainType      TA
# RestingBP         200
# Cholesterol       603
# FastingBS           1
# RestingECG         ST
# MaxHR             202
# ExerciseAngina      Y
# Oldpeak           6.2
# ST_Slope           Up
# HeartDisease        1
# dtype: object

# %%
df.count()
# Out:
# Age               918
# Sex               918
# ChestPainType     918
# RestingBP         918
# Cholesterol       918
# FastingBS         918
# RestingECG        918
# MaxHR             918
# ExerciseAngina    918
# Oldpeak           918
# ST_Slope          918
# HeartDisease      918
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  ...     Oldpeak  HeartDisease
# count  918.000000  918.000000  ...  918.000000    918.000000
# mean    53.510893  132.396514  ...    0.887364      0.553377
# std      9.432617   18.514154  ...    1.066570      0.497414
# min     28.000000    0.000000  ...   -2.600000      0.000000
# 25%     47.000000  120.000000  ...    0.000000      0.000000
# 50%     54.000000  130.000000  ...    0.600000      1.000000
# 75%     60.000000  140.000000  ...    1.500000      1.000000
# max     77.000000  200.000000  ...    6.200000      1.000000
#
# [8 rows x 7 columns]

# %%
#output
#df.to_csv('heart.csv',index=False)

# %%
#excel
#df = pd.read_excel("",sheet_name='')
#df.to_excel('' ,sheet_name='')

# %%
#groupby
df = pd.DataFrame(data={
    'sub':['maths','maths','che','che','phy','phy'],
    'student':['ajith','abi','madhu','sangavi','thiru','niranjana'],
    'mark':[120,200,200,124,154,170]})

# %%
df
# Out:
#      sub    student  mark
# 0  maths      ajith   120
# 1  maths        abi   200
# 2    che      madhu   200
# 3    che    sangavi   124
# 4    phy      thiru   154
# 5    phy  niranjana   170

# %%
df.groupby('sub')

# %%
a=df.groupby('sub')
a.mean()
# Out:
#        mark
# sub
# che     162
# maths   160
# phy     162

# %%
a.describe()
# Out:
#        mark
#       count   mean        std    min    25%    50%    75%    max
# sub
# che     2.0  162.0  53.740115  124.0  143.0  162.0  181.0  200.0
# maths   2.0  160.0  56.568542  120.0  140.0  160.0  180.0  200.0
# phy     2.0  162.0  11.313708  154.0  158.0  162.0  166.0  170.0

# %%
#merging and concatenating
df1 = pd.DataFrame(data={
    'A':['A0','A1','A3','A4'],
    'B':['B0','B1','B2','B3']},index=[0,1,2,3])
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A3  B2
# 3  A4  B3

# %%
df2 = pd.DataFrame(data={
    'A':['A5','A6','A7','A8'],
    'B':['B5','B6','B7','B8']
},index=[4,5,6,7])
df2
# Out:
#     A   B
# 4  A5  B5
# 5  A6  B6
# 6  A7  B7
# 7  A8  B8

# %%
pd.concat([df1,df2])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A3  B2
# 3  A4  B3
# 4  A5  B5
# 5  A6  B6
# 6  A7  B7
# 7  A8  B8

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    A    B
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A3   B2  NaN  NaN
# 3   A4   B3  NaN  NaN
# 4  NaN  NaN   A5   B5
# 5  NaN  NaN   A6   B6
# 6  NaN  NaN   A7   B7
# 7  NaN  NaN   A8   B8

# %%
#merging
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
#operations
df = pd.DataFrame({
    'col1':[1,2,3,4],
    'col2':[444,555,666,444],
    'col3':['abc','def','ghi','xyz']
})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
#information about unique
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
#function
def sqrt(x):
    return x**2

# %%
df['col1'].apply(sqrt)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
#perment delete a column
del df['col3']

# %%
df
# Out:
#    col1  col2
# 0     1   444
# 1     2   555
# 2     3   666
# 3     4   444

# %%
#index and column name
df.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#sorting
df.sort_values(by='col2')
# Out:
#    col1  col2
# 0     1   444
# 3     4   444
# 1     2   555
# 2     3   666

# %%
#find null value
df.isnull()
# Out:
#     col1   col2
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
